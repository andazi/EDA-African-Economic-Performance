# %% [markdown]
# # Project Title: Comparative Analysis of Economic Performance in Multiple African Countries
#
# ## Introduction
#
# In today's interconnected world, understanding and comparing the economic trends and performance of various countries is crucial for policymakers, investors, and researchers. This project aims to conduct a comparative analysis of the economic indicators of multiple countries, using Python and data analysis techniques.
#
# ## Dataset
#
# For this analysis, a dataset containing economic data for several countries is used. The dataset includes information on GDP growth rates, inflation, government expenditure, trade balances, and other relevant economic metrics. This dataset allows for a comprehensive comparison of economic performance across different nations.
#
# ## Objectives
#
# 1. **Data Collection:** Gather and preprocess data for multiple countries to facilitate cross-country comparisons.
#
# 2. **Exploratory Data Analysis (EDA):** Conduct EDA on each country individually, including visualizations, summary statistics, and correlation analysis.
#
# 3. **Cross-Country Comparison:** Compare and contrast economic performance among different countries, identifying global economic trends.
#
# 4. **Store Parameters:** Store parameters and conclusions for each country's analysis, enabling future comparisons.
#
# ## Methodology
#
# 1. **Data Preparation**
#     - Begin by loading the dataset into Python using the Pandas library and filter and cleaned the data to isolate information for multiple countries.
#
# 2. **Data Exploration**
#     - Generate summary statistics for each economic indicator.
#
# 3. **Comparative Analysis**
#     - Group data by countries.
#     - Create bar plots or box plots to compare economic indicators among different countries.
#
# 4. **Economic Growth Analysis**
#     - Use "Real GDP growth (annual %)" for individual country analysis. Identify periods of growth, stagnation, or recession.
#
# 5. **Inflation-Economic Growth Relationship**
#     - Investigate the correlation between "Inflation" and "Real GDP growth."
#
# 6. **Trade Analysis**
#     - Use "Exports of goods and services (% of GDP)" and "Imports of goods and services (% of GDP)" to assess the trade dynamics.
#
# 7. **Investment Analysis**
#     - Analyze "Gross capital formation (% of GDP)" to understand investment trends.
#
# 8. **Balance of Payments Analysis**
#     - Assess the "Current account balance" to understand trade balances.
#
# 9. **Government and Household Spending Analysis**
#     - Explore "General government final consumption expenditure (% of GDP)" and "Household final consumption expenditure (% of GDP)" to study their impact on economic growth.
#
# 10. **Documentation and Conclusion**
#     - Document your findings, insights, and conclusions in Markdown cells. Explain the significance of your analyses and what the data suggests.
#
#
# ## Findings
#
# - Comparative analysis highlights variations in GDP growth trends among different countries.
# - Inflation's impact on GDP growth varies across nations, revealing unique economic dynamics.
# - Cross-country comparisons identify the key drivers of economic performance, allowing for a deeper understanding of global economic trends.
#
# ## Conclusion
#
# This project provides a comprehensive analysis of the economic performance of multiple countries, enabling comparative assessments. The findings shed light on the complex interplay of economic factors and offer insights for policymakers, investors, and researchers looking to make informed decisions in a global context.
#
# ## Future Directions
#
# This analysis serves as a foundation for more in-depth studies by economists and researchers. Future directions may involve incorporating additional economic factors, employing advanced statistical models, and considering socio-political influences on the economic performance of multiple countries.
#
# This project promotes the understanding of global economics, empowering data analysts to assess and compare the economic health of various nations.
#
# Feel free to modify and expand on this outline to create your notebook for analyzing the economic performance of multiple countries.

# %%
# Importing our libraries
import pandas as pd  # Data manipulation
import numpy as np   # Numerical operations
import matplotlib.pyplot as plt  # Data visualization

# %% [markdown]
# ### Data Preparation

# %%
# loading the dataset

dataset = pd.read_csv('data/ObservationData_lavlqce.csv')
dataset.shape
# Out:
# (2322, 31)

# %%
# lets peep at our dataset
dataset.head(2)
# Out:
#   Country  Year  Real per Capita GDP Growth Rate (annual %)  \
# 0  Malawi  1980                                         NaN
# 1  Malawi  1981                                      -13.06
#
#    Real GDP growth (annual %)  Gross domestic product, (constant prices US$)  \
# 0                         NaN                                        3038.14
# 1                      -10.81                                        2709.74
#
#    Gross domestic product, current prices (current US$)  \
# 0                                            2236.36
# 1                                            2236.40
#
#    Final consumption expenditure  (current US$)  \
# 0                                       1104.30
# 1                                       1091.26
#
#    General government final consumption expenditure (current US$)  \
# 0                                             238.76
# 1                                             221.16
#
# ...

# %%
# we won't be using all the column heads for our analysis
# we would select what we would need
# List of selected columns for the analysis
selected_columns = [
    'Country',
    'Year',
    'Real GDP growth (annual %)',
    'Inflation, consumer prices (annual %)',
    'Exports of goods and services (% of GDP)',
    'Imports of goods and services (% of GDP)',
    'Gross capital formation (% of GDP)',
    'Current account balance (Net, BoP, cur. US$)',
    'General government final consumption expenditure (% of GDP)',
    'Household final consumption expenditure  (% of GDP)'
]

dataset_selected = dataset[selected_columns]
dataset_selected.head(2)
# Out:
#   Country  Year  Real GDP growth (annual %)  \
# 0  Malawi  1980                         NaN
# 1  Malawi  1981                      -10.81
#
#    Inflation, consumer prices (annual %)  \
# 0                                    NaN
# 1                                  12.01
#
#    Exports of goods and services (% of GDP)  \
# 0                                     13.75
# 1                                     14.20
#
#    Imports of goods and services (% of GDP)  \
# 0                                     21.48
# 1                                     17.41
#
#    Gross capital formation (% of GDP)  \
# 0                               13.69
# 1                                9.75
#
#    Current account balance (Net, BoP, cur. US$)  \
# 0                                       -207.07
# 1                                        -86.71
#
#    General government final consumption expenditure (% of GDP)  \
# 0                                              10.68
# ...

# %% [markdown]
# #### __Understanding our Dataset and why we chose this columns__
#
# 1. **Country:** You will likely need this column to identify and group data by different African countries.
#
# 2. **Year:** This column allows you to analyze trends over time and conduct time-series analysis.
#
# 3. **Real GDP growth (annual %):** This is a key indicator for studying economic growth trends. It's a common choice for analysis.
#
# 4. **Inflation, consumer prices (annual %):** This can be used to examine the impact of inflation on economic growth.
#
# 5. **Exports of goods and services (% of GDP):** Useful for understanding the importance of exports in a country's economy.
#
# 6. **Imports of goods and services (% of GDP):** Helps analyze the significance of imports in relation to GDP.
#
# 7. **Gross capital formation (% of GDP):** Indicates the investment in a country's economy, which is essential for growth analysis.
#
# 8. **Current account balance (Net, BoP, cur. US$):** Useful for assessing the overall trade balance.
#
# 9. **General government final consumption expenditure (% of GDP):** Offers insights into government spending.
#
# 10. **Household final consumption expenditure (% of GDP):** Reflects consumer spending.

# %% [markdown]
# ### With the above selected columns or indicators. we can do the following analysis:
#
# 1. **Trend Analysis**: Use the "Year" column to analyze trends in economic indicators over time. This can help identify patterns, cycles, and changes in the economic performance of African countries.
#
# 2. **Comparative Analysis**: Compare the economic performance of different African countries. You can group and analyze countries based on their economic indicators, allowing for cross-country comparisons.
#
# 3. **Economic Growth Analysis**: Utilize "Real GDP growth (annual %)" to study the economic growth trends of individual countries. You can identify periods of growth, stagnation, or recession.
#
# 4. **Inflation-Economic Growth Relationship**: Investigate the correlation between "Inflation, consumer prices (annual %)" and "Real GDP growth." Analyze how changes in inflation rates impact economic growth.
#
# 5. **Trade Analysis**: Examine the importance of international trade in each country's economy using "Exports of goods and services (% of GDP)" and "Imports of goods and services (% of GDP)." This can help assess a country's trade balance and economic openness.
#
# 6. **Investment Analysis**: Study "Gross capital formation (% of GDP)" to understand the level of investment in the economy. High capital formation can be an indicator of future economic growth.
#
# 7. **Balance of Payments Analysis**: Assess the overall trade balance with "Current account balance (Net, BoP, cur. US$)." A positive balance indicates a surplus, while a negative balance indicates a deficit.
#
# 8. **Government and Household Spending Analysis**: Explore the role of government and household consumption in economic performance using "General government final consumption expenditure (% of GDP)" and "Household final consumption expenditure (% of GDP)." These figures can offer insights into consumer and government-driven economic growth.
#
# These analyses can provide a comprehensive understanding of the economic landscape in different African countries. You can identify factors that influence economic growth, assess the impact of government policies, and gain insights into trade dynamics. The choice of analysis will depend on your specific research questions and objectives.

# %%
# check for empty or null values

dataset_selected.isna().sum() # we observed that there are just two missing data
# Out:
# Country                                                          0
# Year                                                             0
# Real GDP growth (annual %)                                      84
# Inflation, consumer prices (annual %)                          154
# Exports of goods and services (% of GDP)                        83
# Imports of goods and services (% of GDP)                        83
# Gross capital formation (% of GDP)                              83
# Current account balance (Net, BoP, cur. US$)                   118
# General government final consumption expenditure (% of GDP)     83
# Household final consumption expenditure  (% of GDP)             83
# dtype: int64

# %%
# i would be dropping the missing dataset
dataset_cleaned = dataset_selected.dropna()

# %%
# checking dataset
dataset_cleaned.isna().sum()
# Out:
# Country                                                        0
# Year                                                           0
# Real GDP growth (annual %)                                     0
# Inflation, consumer prices (annual %)                          0
# Exports of goods and services (% of GDP)                       0
# Imports of goods and services (% of GDP)                       0
# Gross capital formation (% of GDP)                             0
# Current account balance (Net, BoP, cur. US$)                   0
# General government final consumption expenditure (% of GDP)    0
# Household final consumption expenditure  (% of GDP)            0
# dtype: int64

# %%
# checking the datatype of each columns
dataset_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2113 entries, 1 to 2321
# Data columns (total 10 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Country                                                      2113 non-null   object
#  1   Year                                                         2113 non-null   int64
#  2   Real GDP growth (annual %)                                   2113 non-null   float64
#  3   Inflation, consumer prices (annual %)                        2113 non-null   float64
#  4   Exports of goods and services (% of GDP)                     2113 non-null   float64
#  5   Imports of goods and services (% of GDP)                     2113 non-null   float64
#  6   Gross capital formation (% of GDP)                           2113 non-null   float64
# ...

# %%
# let save our clean dataset_cleaned as csv file for future use
# you can uncomment the below code to save file

# dataset_cleaned.to_csv('data/cleaned African economic dataset.csv')

# %%
# we would be listing the countries in the dataset and store them for the future

african_countries = dataset_selected.Country.unique()
african_countries
# Out:
# array(['Malawi', 'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Burundi', 'Cameroon', 'Cabo Verde', 'Central African Republic',
#        'Chad', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        "Cote d'Ivoire", 'Djibouti', 'Egypt', 'Equatorial Guinea',
#        'Eritrea', 'eSwatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya',
#        'Madagascar', 'Mali', 'Mauritania', 'Mauritius', 'Morocco',
#        'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania',
#        'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'], dtype=object)

# %% [markdown]
# ### Data Exploration

# %%
dataset_cleaned.describe() # general statistics on our dataset
# Out:
#               Year  Real GDP growth (annual %)  \
# count  2113.000000                 2113.000000
# mean   2002.290109                    3.755376
# std      12.024028                    7.886324
# min    1981.000000                  -66.657000
# 25%    1992.000000                    1.620000
# 50%    2003.000000                    3.921229
# 75%    2013.000000                    6.112343
# max    2022.000000                  124.709000
#
#        Inflation, consumer prices (annual %)  \
# count                            2113.000000
# mean                               12.564782
# std                                29.744734
# min                               -88.600000
# 25%                                 2.698450
# 50%                                 6.220000
# 75%                                12.450000
# max                               622.751634
#
#        Exports of goods and services (% of GDP)  \
# count                               2113.000000
# ...

# %% [markdown]
# We can see few findings based on the general statistics such as significant values such as max, min
#
# Real GDP growth (annual %) of 124.709% as the massive growth in the REAL GDP GROWTH
#
# Real GDP growth (annual %) of -66.657% as the lowest growth in the REAL GDP GROWTH
#
# We can also single out the countries and the year to which any of those significant change in the Economy

# %%
# Let's get the data of the country with the maximum Inflation rate
dataset_cleaned[dataset_cleaned['Inflation, consumer prices (annual %)'] == dataset_cleaned['Inflation, consumer prices (annual %)'].max()]
# Out:
#        Country  Year  Real GDP growth (annual %)  \
# 2319  Zimbabwe  2020                  -10.011501
#
#       Inflation, consumer prices (annual %)  \
# 2319                             622.751634
#
#       Exports of goods and services (% of GDP)  \
# 2319                                  21.70701
#
#       Imports of goods and services (% of GDP)  \
# 2319                                 23.594682
#
#       Gross capital formation (% of GDP)  \
# 2319                            5.026764
#
#       Current account balance (Net, BoP, cur. US$)  \
# 2319                                   -348.597609
#
#       General government final consumption expenditure (% of GDP)  \
# 2319                                          11.777531
#
#       Household final consumption expenditure  (% of GDP)
# 2319                                          85.083377

# %%
# getting the data of the country with the minimum Real GDP growth
dataset_cleaned[dataset_cleaned['Real GDP growth (annual %)'] == dataset_cleaned['Real GDP growth (annual %)'].min()]
# Out:
#      Country  Year  Real GDP growth (annual %)  \
# 1278   Libya  2011                     -66.657
#
#       Inflation, consumer prices (annual %)  \
# 1278                                 15.902
#
#       Exports of goods and services (% of GDP)  \
# 1278                                 71.470137
#
#       Imports of goods and services (% of GDP)  \
# 1278                                 28.567192
#
#       Gross capital formation (% of GDP)  \
# 1278                           35.513318
#
#       Current account balance (Net, BoP, cur. US$)  \
# 1278                                    3173.02084
#
#       General government final consumption expenditure (% of GDP)  \
# 1278                                          10.703707
#
#       Household final consumption expenditure  (% of GDP)
# 1278                                           10.88003

# %%
# creating a key value pair, using the shorter name for the real country names

country_names = {
    'DZA': 'Algeria',
    'AGO': 'Angola',
    'BEN': 'Benin',
    'BWA': 'Botswana',
    'BFA': 'Burkina Faso',
    'BDI': 'Burundi',
    'CMR': 'Cameroon',
    'CPV': 'Cabo Verde',
    'CAF': 'Central African Republic',
    'TCD': 'Chad',
    'COM': 'Comoros',
    'COD': 'Congo, Dem. Rep.',
    'COG': 'Congo, Rep.',
    'CIV': "Cote d'Ivoire",
    'DJI': 'Djibouti',
    'EGY': 'Egypt',
    'GNQ': 'Equatorial Guinea',
    'ERI': 'Eritrea',
    'SWZ': 'eSwatini',
    'ETH': 'Ethiopia',
    'GAB': 'Gabon',
    'GMB': 'Gambia',
    'GHA': 'Ghana',
    'GIN': 'Guinea',
    'GNB': 'Guinea-Bissau',
    'KEN': 'Kenya',
    'LSO': 'Lesotho',
    'LBR': 'Liberia',
    'LBY': 'Libya',
    'MDG': 'Madagascar',
    'MWI': 'Malawi',
    'MLI': 'Mali',
    'MRT': 'Mauritania',
    'MUS': 'Mauritius',
    'MAR': 'Morocco',
    'MOZ': 'Mozambique',
    'NAM': 'Namibia',
    'NER': 'Niger',
    'NGA': 'Nigeria',
    'RWA': 'Rwanda',
    'STP': 'Sao Tome and Principe',
    'SEN': 'Senegal',
    'SYC': 'Seychelles',
    'SLE': 'Sierra Leone',
    'SOM': 'Somalia',
    'ZAF': 'South Africa',
    'SSD': 'South Sudan',
    'SDN': 'Sudan',
    'TZA': 'Tanzania',
    'TGO': 'Togo',
    'TUN': 'Tunisia',
    'UGA': 'Uganda',
    'ZMB': 'Zambia',
    'ZWE': 'Zimbabwe'
}

# %%
# economic indicators

x = ['country', 'year', 'gdp_growth', 'inflation', 'exports_gdp', 'imports_gdp', 'capital_formation_gdp', 'current_account_balance', 'govt_consumption_gdp', 'household_consumption_gdp']

for a,b in zip(x, selected_columns): 
    print(f'{a} = "{b}"')
# Out:
# country = "Country"
# year = "Year"
# gdp_growth = "Real GDP growth (annual %)"
# inflation = "Inflation, consumer prices (annual %)"
# exports_gdp = "Exports of goods and services (% of GDP)"
# imports_gdp = "Imports of goods and services (% of GDP)"
# capital_formation_gdp = "Gross capital formation (% of GDP)"
# current_account_balance = "Current account balance (Net, BoP, cur. US$)"
# govt_consumption_gdp = "General government final consumption expenditure (% of GDP)"
# household_consumption_gdp = "Household final consumption expenditure  (% of GDP)"

# %%
# economic indicators

year = "Year"
gdp_growth = "Real GDP growth (annual %)"
inflation = "Inflation, consumer prices (annual %)"
exports_gdp = "Exports of goods and services (% of GDP)"
imports_gdp = "Imports of goods and services (% of GDP)"
capital_formation_gdp = "Gross capital formation (% of GDP)"
current_account_balance = "Current account balance (Net, BoP, cur. US$)"
govt_consumption_gdp = "General government final consumption expenditure (% of GDP)"
household_consumption_gdp = "Household final consumption expenditure  (% of GDP)"

# %%
dataset_cleaned[household_consumption_gdp]
# Out:
# 1       38.910000
# 2       37.640000
# 3       37.950000
# 4       38.900000
# 5       38.740000
#           ...
# 2317    75.858995
# 2318    83.325020
# 2319    85.083377
# 2320    85.721569
# 2321    86.070534
# Name: Household final consumption expenditure  (% of GDP), Length: 2113, dtype: float64

# %%
# creating a funtion that accepts 4 arguments

def plot(country = 'NGA', x_indicator = year, y_indicator = gdp_growth, chart = 'line'):
    
    """
    Function to plot economic indicators.

    Parameters:
    - country: The country code (e.g., 'NGA' for Nigeria)
    - x_indicator: The economic indicator for the x-axis (e.g., 'GDP Growth')
    - y_indicator: The economic indicator for the y-axis (e.g., 'Year')
    - chart: The type of chart (e.g., 'line', 'bar', 'scatter')

    Example usage:
    plot('NGA', year, gdp_growth, 'line')
    """
    
    country = country.upper()
    chart = chart.title()

    unique_country = dataset_cleaned[dataset_cleaned.Country == country_names[country]]
 
    x_indicator = unique_country[x_indicator]
    y_indicator = unique_country[y_indicator]
    
    
    fig,axs = plt.subplots(figsize=(15, 10)) 
    
    if chart == 'Line':
        axs.plot(x_indicator, y_indicator, color='blue', label= f'{x_indicator.name} vs {y_indicator.name} Trend', linestyle='-', marker='o')
        axs.set_xlabel(x_indicator.name)
        axs.set_ylabel(y_indicator.name)
        axs.set_title(f'Line Plot: {x_indicator.name} vs {y_indicator.name}Trends for {country_names[country]}')
        axs.grid(linestyle='--', alpha=0.6)
        axs.legend()
    elif chart == 'Bar':
        axs.bar(x_indicator, y_indicator, color='green', label= f'{x_indicator.name} vs {y_indicator.name} Trend')
        axs.set_xlabel(x_indicator.name)
        axs.set_ylabel(y_indicator.name)
        axs.set_title(f'Bar Plot: {x_indicator.name} vs {y_indicator.name} Trends for {country_names[country]}')
        axs.grid(linestyle='--', alpha=0.6)
        axs.legend()
        axs.set_xticks(x_indicator)  
        axs.set_xticklabels(x_indicator, rotation=45)  
        

    elif chart == 'Scatter':
        # Create the scatter plot
        axs.scatter(x_indicator, y_indicator, color='purple', label= f'{x_indicator.name} vs {y_indicator.name} Trend', marker='o')
        axs.set_xlabel(x_indicator.name)
        axs.set_ylabel(y_indicator.name)
        axs.set_title(f'Scatter Plot: {x_indicator.name} vs {y_indicator.name}Trends for {country_names[country]}', loc='left')
        axs.grid(True)

        axs.legend()

        # Calculate the regression line
        regression_model = np.polyfit(x_indicator, y_indicator, 1)
        regression_line = np.poly1d(regression_model)

        # Plot the regression line
        x_range = np.linspace(min(x_indicator), max(x_indicator)+5, 100)  # Create a range of x values
        axs.plot(x_range, regression_line(x_range), color='red', linestyle='--', label='Regression Line')

        axs.legend()

    else:
        print("please choose from availble plot")

    # show plot
    plt.show()
    # saving graph
    #fig.savefig(f'images/{chart} Plot: GDP Growth Trends for {country_names[country]}.png')

# %%
# plot graph
plot()

# %%
# CHECKING EGYPT GDP GROWTH TREND

plot('EGY', year, gdp_growth, 'line')

# %%
plot('EGY', year, gdp_growth, 'bar')

# %%
# CHECKING Sao Tome and Principe GDP GROWTH TREND

plot('STP', year, gdp_growth, 'scatter')

# %%
plot('STP', inflation, gdp_growth, 'scatter')

# %%
# creating a funtion that accepts 3 or more arguments

def econ_comparison(country_1, country_2, x_indicator, y_indicator):
    
    """
    Function to plot economic trends.

    Parameters:
    - country_1:  country one code  (e.g., 'NGA' for Nigeria)
    - country_2:  country two code  (e.g., 'NER' for Niger)
    - x_indicator: The economic indicator for the x-axis (e.g., 'GDP Growth')
    - y_indicator: The economic indicator for the y-axis (e.g., 'Year')
  
    Example usage:
    plot('NGA', 'STP', year, inflation)
    """
    
    country_1 = country_1.upper()
    country_2 = country_2.upper()
    
    
    fig,axs = plt.subplots(figsize=(15,10))

    countries = [country_1, country_2]
    colors = ['green', 'red', 'purple']
    i = 0

    for county in countries:
        country_datset = dataset_cleaned[dataset_cleaned.Country == country_names[county]]
        axs.plot(country_datset[year], country_datset[gdp_growth], color=colors[i], label=f'{country_names[county]} line plot')
        i += 1

    axs.set_xlabel(x_indicator)
    axs.set_ylabel(y_indicator)
    axs.set_title(f'Line plot: {x_indicator} vs {y_indicator} Comparison Between {country_names[country_1]} and {country_names[country_2]}')

    axs.legend()
  

    # show plot
    plt.show()
    # saving graph
    #fig.savefig(f'images/Line plot: {x_indicator} vs {y_indicator} Comparison Between {country_names[country_1]} and {country_names[country_2]}.png')

# %%
econ_comparison('NGA', 'STP', year, inflation)

# %%
econ_comparison('NGA', 'NER', year, imports_gdp)

# %%
import seaborn as sns

# Group data by countries
country_groups = dataset_cleaned.groupby('Country')

# Create a bar plot for Real GDP growth by country
plt.figure(figsize=(20, 15))
sns.barplot(x='Country', y='Real GDP growth (annual %)', data=dataset_cleaned)
plt.xlabel('Country')
plt.ylabel('Real GDP Growth (annual %)')
plt.title('Real GDP Growth by Country')
plt.xticks(rotation=45)
plt.show()
